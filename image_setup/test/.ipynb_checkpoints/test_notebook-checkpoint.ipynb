# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore
import matplotlib.pyplot as plt
import seaborn as sns
import random
import folium
import os, shutil
if 'results' in os.listdir(): shutil.rmtree('results')
os.mkdir('results')

'''
Source: https://www.kaggle.com/competitions/store-sales-time-series-forecasting
Dataset: train.csv
store_nbr: the store at which the products are sold.
family: the type of product sold.
sales: the total sales for a product family at a particular store at a given date. 
Fractional values are possible since products can be sold in fractional units 
(1.5 kg of cheese, for instance, as opposed to 1 bag of chips).
onpromotion: the total number of items in a product family that were being promoted at a store at a given date.
'''
print('Pandas dataframe: Sales data')
sales = pd.read_csv('../../data/sales.csv.zip')
sales = sales.rename(columns={'family':'product_type', 'store_nbr': 'store_id'})
# Remove product categories
categories = ['GROCERY I', 'GROCERY II', 'HOME AND KITCHEN I', 'HOME AND KITCHEN II']
sales = sales[~sales['product_type'].isin(categories)]
print(sales.head())
# Out:
# Pandas dataframe: Sales data
#    id        date  store_id product_type  sales  onpromotion
# 0   0  2013-01-01         1   AUTOMOTIVE    0.0            0
# 1   1  2013-01-01         1    BABY CARE    0.0            0
# 2   2  2013-01-01         1       BEAUTY    0.0            0
# 3   3  2013-01-01         1    BEVERAGES    0.0            0
# 4   4  2013-01-01         1        BOOKS    0.0            0

# %%
print('Sales values')
print(sales['sales'].value_counts())
# Out:
# Sales values
# sales
# 0.000        857711
# 1.000        110597
# 2.000         80209
# 3.000         62530
# 4.000         51449
#               ...
# 498.344           1
# 1458.517          1
# 1362.213          1
# 10989.000         1
# 2419.729          1
# Name: count, Length: 362770, dtype: int64

# %%
print('Sales grouped by family')
sales_sum = sales.groupby('product_type')['sales'].sum()
sales_sum = pd.DataFrame(list(zip(sales_sum.index, sales_sum.values)), columns = ['product', 'items'])
sales_sum['z_score'] = sales_sum[['items']].transform(zscore)
print('mean zscore=', np.mean(np.abs((sales_sum['z_score']))))
# Out:
# Sales grouped by family
# mean zscore= 0.6365824644746042

# %% [markdown]
# ## Bar Plot Data

# %%
bar_plot_data = sales_sum[sales_sum['product'].isin(['EGGS', 'DAIRY', 'MEATS', 'POULTRY', 'SEAFOOD', 'BREAD/BAKERY'])]
# Add locations
loc = (51.5072, 0.1276)  # London 51.5072° N, 0.1276° W
locations = [(loc[0]+i, loc[1]+i) for i in np.arange(0.1,0.7, 0.1)]
sales_sum['location'] = random.choices(locations, k=len(sales_sum))
print(bar_plot_data)
# Out:
#          product         items   z_score
# 5   BREAD/BAKERY  4.213395e+07  0.366383
# 8          DAIRY  6.448771e+07  0.844228
# 10          EGGS  1.558830e+07 -0.201069
# 20         MEATS  3.108647e+07  0.130227
# 24       POULTRY  3.187600e+07  0.147105
# 28       SEAFOOD  2.015432e+06 -0.491209

# %% [markdown]
# # Plots

# %% [markdown]
# ## Matplotlib

# %%
print('Prepare and save bar plots')
bar_colors = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange']
food, sum = list(bar_plot_data['product']), list(bar_plot_data['items'])
plt.bar(food, sum, color=bar_colors)
plt.show()
# Out:
# Prepare and save bar plots

# %% [markdown]
# ## Seaborn

# %%
sns.barplot(x='product', y='items', data=bar_plot_data)
plt.show()

# %% [markdown]
# ## Bokeh

# %%
from bokeh.models import ColumnDataSource
from bokeh.palettes import Bright6
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.transform import factor_cmap
source = ColumnDataSource(data=dict(food=food, sum=sum))
TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,\
box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,examine,help"
p = figure(x_range=food, height=350, tools=TOOLS, title="Fruit sum")
p.vbar(x='food', top='sum', width=0.9, source=source, legend_field="food",
       line_color='white', fill_color=factor_cmap('food', palette=Bright6, factors=food))
p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
output_notebook()
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c816e3a3-81eb-4b84-b2c0-ee3af7da1475">Loading BokehJS ...</span>
#     </div>
#   <div id="dfe35fde-c665-41a4-a02f-fc9711ff84c6" data-root-id="p1004" style="display: contents;"></div>

# %% [markdown]
# ## Folium map

# %%
m = folium.Map(location=loc, zoom_start=4)
tooltip = "Click me!"
for location in locations:
    folium.Marker(location, popup="<i>Mt. Hood Meadows</i>", tooltip=tooltip).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_616595f7dd67727c879ba4ebd67ea2c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_616595f7dd67727c879ba4ebd67ea2c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_616595f7dd67727c879ba4ebd67ea2c1 = L.map(
#                 &quot;map_616595f7dd67727c879ba4ebd67ea2c1&quot;,
#                 {
#                     center: [51.5072, 0.1276],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b8f302471c90f75de67391125997c60 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_616595f7dd67727c879ba4ebd67ea2c1);
#
#
#             var marker_990a5b99566a96d143eb903cba8dc2d7 = L.marker(
#                 [51.6072, 0.2276],
#                 {}
#             ).addTo(map_616595f7dd67727c879ba4ebd67ea2c1);
#
#
#         var popup_59b2251d4d72ba77b65918290657bab6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b57867a57fa5d5602f601b5e1f06c580 = $(`&lt;div id=&quot;html_b57867a57fa5d5602f601b5e1f06c580&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Mt. Hood Meadows&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_59b2251d4d72ba77b65918290657bab6.setContent(html_b57867a57fa5d5602f601b5e1f06c580);
#
#
#
#         marker_990a5b99566a96d143eb903cba8dc2d7.bindPopup(popup_59b2251d4d72ba77b65918290657bab6)
#         ;
#
#
#
#
#             marker_990a5b99566a96d143eb903cba8dc2d7.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b8e9bf5f07abfc703f0a4f1aa796c379 = L.marker(
#                 [51.7072, 0.3276],
#                 {}
#             ).addTo(map_616595f7dd67727c879ba4ebd67ea2c1);
#
#
#         var popup_6f751fc1fbb5f5eeba0e79a48d87f628 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec60c316061272c802e3a2c4ec434259 = $(`&lt;div id=&quot;html_ec60c316061272c802e3a2c4ec434259&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Mt. Hood Meadows&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_6f751fc1fbb5f5eeba0e79a48d87f628.setContent(html_ec60c316061272c802e3a2c4ec434259);
#
#
#
#         marker_b8e9bf5f07abfc703f0a4f1aa796c379.bindPopup(popup_6f751fc1fbb5f5eeba0e79a48d87f628)
#         ;
#
#
#
#
#             marker_b8e9bf5f07abfc703f0a4f1aa796c379.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_070ae778751dea598bc422d04fba264d = L.marker(
#                 [51.807199999999995, 0.42760000000000004],
#                 {}
#             ).addTo(map_616595f7dd67727c879ba4ebd67ea2c1);
#
#
#         var popup_81ae9cbc349398579e4dacc1a7ddf5c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07575a38d492b37345f3260fcaa95bc5 = $(`&lt;div id=&quot;html_07575a38d492b37345f3260fcaa95bc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Mt. Hood Meadows&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_81ae9cbc349398579e4dacc1a7ddf5c9.setContent(html_07575a38d492b37345f3260fcaa95bc5);
#
#
#
#         marker_070ae778751dea598bc422d04fba264d.bindPopup(popup_81ae9cbc349398579e4dacc1a7ddf5c9)
#         ;
#
#
#
#
#             marker_070ae778751dea598bc422d04fba264d.bindTooltip(
#                 `&lt;div&gt;
#                      Click me!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_40a6ac954ffbcf937365293d645464f1 = L.marker(
#                 [51.907199999999996, 0.5276000000000001],
#                 {}
#             ).addTo(map_616595f7dd67727c879ba4ebd67ea2c1);
#
#
#         var popup_f983dca89a427a868aaca7089227bcec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21f255f6fbc3017aeb823d6af23d678b = $(`&lt;div id=&quot;html_21f255f6fbc3017aeb823d6af23d678b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Mt. Hood Meadows&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_f983dca89a427a868aaca7089227bcec.setContent(html_21f255f6fbc3017aeb823d6af23d678b);
#
#
#
#         marker_40a6ac954ffbcf937365293d645464f1.bindPopup(popup_f983dca89a427a868aaca7089227bcec)
#         ;
#
#
#
#
#             marker_40a6ac954ffbcf937365293d645464f1.bindTooltip(
#                 `&lt;div&gt;
#                      Click
